# %%
from astropy.io.votable import parse_single_table

# tbl = parse_single_table("vizier_cats/J_ApJ_852_108__0.vot").to_table()
tbl = parse_single_table("vizier_cats/J_ApJ_920_127__0.vot").to_table()
# print(np.unique(tbl["Filt"]))

# %%
tbl
# Out:
# <Table length=453>
#   MJD     Phase           Tel           Band l_mag   mag    e_mag
#    d        d                                        mag     mag
# float64  float32         str21          str5  str1 float32 float32
# -------- ------- --------------------- ----- ----- ------- -------
# 58752.21    0.09                 DLT40  Open         17.38    0.07
# 58752.22    0.10                 DLT40  Open         17.34    0.07
# 58752.22    0.10                 DLT40  Open         17.39    0.07
# 58752.23    0.11                 DLT40  Open         17.40    0.07
# 58752.25    0.13                 DLT40  Open         17.41    0.07
# 58752.25    0.13                 DLT40  Open         17.42    0.07
# 58752.25    0.13 LasCumbres1m/Sinistro    rp         17.52    0.01
# 58752.25    0.13 LasCumbres1m/Sinistro    up         17.39    0.03
# 58752.25    0.13 LasCumbres1m/Sinistro    gp         17.34    0.01
#      ...     ...                   ...   ...   ...     ...     ...
# ...
